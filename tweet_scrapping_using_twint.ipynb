# %% [markdown]
# <a href="https://colab.research.google.com/github/VxDant/Sentiment-Analysis/blob/main/tweet_scrapping_using_twint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers
# Out:
# ...
#      |████████████████████████████████| 2.1MB 5.8MB/s
# ...
#      |████████████████████████████████| 901kB 41.3MB/s
# ...
#      |████████████████████████████████| 3.3MB 43.6MB/s
# ...

# %%
#install twint, nest_asyncio
! pip install -qq twint
! pip install -qq nest_asyncio

# %%
pip install --user --upgrade -e git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# Out:
# Obtaining twint from git+https://github.com/twintproject/twint.git@origin/master#egg=twint
#   Cloning https://github.com/twintproject/twint.git (to revision origin/master) to ./src/twint
#   Running command git clone -q https://github.com/twintproject/twint.git /content/src/twint
#   WARNING: Did not find branch or tag 'origin/master', assuming revision or ref.
#   Running command git checkout -q origin/master
# ...
#   Found existing installation: twint 2.1.20
#     Uninstalling twint-2.1.20:
#       Successfully uninstalled twint-2.1.20
#   Running setup.py develop for twint
# ...

# %%
import twint

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
c = twint.Config()

# %%
c.Search = "covid"
c.Lang = "en"
c.Limit = 100
c.Pandas = True
twint.run.Search(c)
# Out:
# 1389900540109279237 2021-05-05 11:11:26 +0000 <issabella_isab> @vpartal @VilaWeb No entenc com madriz ha pogut votar majoritàriament aquesta dona que no té projecte, que té un munt de morts per covid i que només sap parlar -malament- de Catalunya..
# 1389900539492585472 2021-05-05 11:11:26 +0000 <opiniondezamora> ÚLTIMA HORA | Parte COVID de este miércoles en #Zamora.   https://t.co/B15ATMrOhP
# 1389900539295502339 2021-05-05 11:11:26 +0000 <ABHISHE07654750> Enough is enough. Save precious lives of Frontline Covid Warriors  #VaccinateBankers #BankBachaoDeshBachao  @PMOIndia  @FinMinIndia  @DFS_India  @MoHFW_INDIA
# 1389900538209128453 2021-05-05 11:11:26 +0000 <khushalsrivas> @BesuraTaansane @narendramodi sir, let him concentrate on covid situation 🙏🙏 lot need to be done, everyday center is getting scolding from court for oxygen
# ...

# %%
def twint_to_pd(columns):
  return twint.output.panda.Tweets_df[columns]

# %%
import pandas as pd
import nltk
from nltk import sent_tokenize, word_tokenize
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
import re
import string

# %%
def columne_names():
  return twint.output.panda.Tweets_df.columns

# %%
data = twint_to_pd(["tweet"])

# %%
data.head(10)
# Out:
#                                                tweet
# 0  @vpartal @VilaWeb No entenc com madriz ha pogu...
# 1  ÚLTIMA HORA | Parte COVID de este miércoles en...
# 2  Enough is enough. Save precious lives of Front...
# 3  @BesuraTaansane @narendramodi sir, let him con...
# 4  All CHILDLINEs, CWCs, DCPUs, OSCs and staff of...
# 5  End Times Idiot Rick Wiles Super-Psyched About...
# 6  Read how @BartsHealthRes1 has aided the UK REC...
# 7  Eu adoro o fato de que pessoas com um número s...
# 8  #Oil demand has revived as #COVID retreats. It...
# 9  Cara, olhando uns depoimentos da CPI da Covid ...

# %%
len(data)
# Out:
# 100

# %%
list1 = data["tweet"].tolist()

# %%
pip install transformers

# %%
from transformers import pipeline

# %%
sentiment_classifier = pipeline('sentiment-analysis')

# %%
resultss = sentiment_classifier(list1)

# %%
ind = 0
for result in resultss:
  print("**********************************\n")
  print(list1[ind] + "\n")
  print(f"label: {result['label']}, with score: {round(result['score'], 4)} ")
  print("*************************************\n")
  ind = ind+1
# Out:
# **********************************
#
# @vpartal @VilaWeb No entenc com madriz ha pogut votar majoritàriament aquesta dona que no té projecte, que té un munt de morts per covid i que només sap parlar -malament- de Catalunya..
#
# label: NEGATIVE, with score: 0.9859
# *************************************
#
# **********************************
#
# ÚLTIMA HORA | Parte COVID de este miércoles en #Zamora.   https://t.co/B15ATMrOhP
#
# label: NEGATIVE, with score: 0.9852
# *************************************
#
# **********************************
#
# Enough is enough. Save precious lives of Frontline Covid Warriors  #VaccinateBankers #BankBachaoDeshBachao  @PMOIndia  @FinMinIndia  @DFS_India  @MoHFW_INDIA
#
# label: NEGATIVE, with score: 0.635
# *************************************
#
# **********************************
#
# @BesuraTaansane @narendramodi sir, let him concentrate on covid situation 🙏🙏 lot need to be done, everyday center is getting scolding from court for oxygen
#
# ...
